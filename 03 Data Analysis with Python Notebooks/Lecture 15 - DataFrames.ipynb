# %% [markdown]
# ### DATA FRAMES

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
import webbrowser
website='http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame.Team
# Out:
# 0           Dallas Cowboys
# 1        Green Bay Packers
# 2     New England Patriots
# 3            Chicago Bears
# 4         Baltimore Ravens
# 5           Miami Dolphins
# 6        Minnesota Vikings
# 7      San Francisco 49ers
# 8          New York Giants
# 9           Denver Broncos
# 10      Kansas City Chiefs
# 11     Pittsburgh Steelers
# 12      Indianapolis Colts
# 13       Las Vegas Raiders
# 14        Seattle Seahawks
# 15        Los Angeles Rams
# 16     Washington Redskins
# 17    Los Angeles Chargers
# 18     Philadelphia Eagles
# 19       Carolina Panthers
# 20        Cleveland Browns
# 21        Tennessee Titans
# 22           Buffalo Bills
# 23      New Orleans Saints
# 24           Detroit Lions
# 25          Houston Texans
# 26           New York Jets
# 27      Cincinnati Bengals
# 28         Atlanta Falcons
# 29    Jacksonville Jaguars
# 30       Arizona Cardinals
# 31    Tampa Bay Buccaneers
# Name: Team, dtype: object

# %%
DataFrame(nfl_frame,columns=['Won','GP','Team','Nomvula'])
# Out:
#     Won     GP                  Team  Nomvula
# 0   520    914        Dallas Cowboys      NaN
# 1   756  1,368     Green Bay Packers      NaN
# 2   512    916  New England Patriots      NaN
# 3   769  1,402         Chicago Bears      NaN
# 4   214    384      Baltimore Ravens      NaN
# 5   457    832        Miami Dolphins      NaN
# 6   488    902     Minnesota Vikings      NaN
# 7   545  1,034   San Francisco 49ers      NaN
# 8   696  1,337       New York Giants      NaN
# 9   483    916        Denver Broncos      NaN
# 10  481    916    Kansas City Chiefs      NaN
# 11  636  1,224   Pittsburgh Steelers      NaN
# 12  523    998    Indianapolis Colts      NaN
# 13  473    916     Las Vegas Raiders      NaN
# 14  355    692      Seattle Seahawks      NaN
# 15  577  1,167      Los Angeles Rams      NaN
# 16  603  1,234   Washington Redskins      NaN
# 17  452    916  Los Angeles Chargers      NaN
# 18  586   1,22   Philadelphia Eagles      NaN
# ...

# %%
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %%
nfl_frame.head(3)
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1        Dallas Cowboys    914  520   388     6  0.572
# 1     2     Green Bay Packers  1,368  756   574    38  0.567
# 2     3  New England Patriots    916  512   395     9  0.564
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1960   AFC East

# %%
nfl_frame.tail(1)
# Out:
#     Rank                  Team   GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 31    32  Tampa Bay Buccaneers  692  267   424     1  0.387              1976
#
#      Division
# 31  NFC South

# %%
nfl_frame.loc[3]
# Out:
# Rank                            4
# Team                Chicago Bears
# GP                          1,402
# Won                           769
# Lost                          591
# Tied                           42
# Pct.                        0.563
# First NFL Season             1920
# Division                NFC North
# Name: 3, dtype: object

# %%
nfl_frame.iloc[1]
# Out:
# Rank                                2
# Team                Green Bay Packers
# GP                              1,368
# Won                               756
# Lost                              574
# Tied                               38
# Pct.                            0.567
# First NFL Season                 1921
# Division                    NFC North
# Name: 1, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %%
nfl_frame['Stadium'] = np.arange(32)

# %%
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %% [markdown]
# ### ADDING A SERIES TO A DATAFRAME

# %%
stadiums = Series(["Levi's Stadium","AT&T Stadium"],index=[9,0])

# %%
stadiums
# Out:
# 9    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %% [markdown]
# ### deleting rows and columns

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#     Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0      1        Dallas Cowboys    914  520   388     6  0.572
# 1      2     Green Bay Packers  1,368  756   574    38  0.567
# 2      3  New England Patriots    916  512   395     9  0.564
# 3      4         Chicago Bears  1,402  769   591    42  0.563
# 4      5      Baltimore Ravens    384  214   169     1  0.559
# 5      6        Miami Dolphins    832  457   371     4  0.552
# 6      7     Minnesota Vikings    902  488   403    11  0.547
# 7      8   San Francisco 49ers  1,034  545   475    14  0.534
# 8      9       New York Giants  1,337  696   608    33  0.533
# 9     10        Denver Broncos    916  483   423    10  0.533
# 10    11    Kansas City Chiefs    916  481   423    12  0.532
# 11    12   Pittsburgh Steelers  1,224  636   566    22  0.529
# 12    13    Indianapolis Colts    998  523   468     7  0.528
# 13    14     Las Vegas Raiders    916  473   432    11  0.522
# ...

# %% [markdown]
# ### CONSTRUCTION OF DATA FRAMES BY COPYING AND DICTIONERIES

# %%
data = DataFrame({'City':['SF','LA','NYC'],'Population':[837000,3880000,8400000]})
data
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000

# %%
import webbrowser
website = 'http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True

# %%
name = input('Enter your name: ')

def say_hi():
    print('Hello ' + name + '!')
    
say_hi()
# Out:
# Enter your name: princess
# Hello princess!
