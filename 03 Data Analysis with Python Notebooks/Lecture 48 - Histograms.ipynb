# %%
#standard imports
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#stats
from scipy import stats

# %%
#plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
#plotting the histogram

# %%
plt.hist(dataset1)
# Out:
# (array([ 4.,  5.,  9., 18., 17., 17., 12., 12.,  5.,  1.]),
#  array([-2.22889125, -1.78383377, -1.33877629, -0.8937188 , -0.44866132,
#         -0.00360384,  0.44145365,  0.88651113,  1.33156861,  1.7766261 ,
#          2.22168358]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)

# %%
plt.hist((dataset2),color='indianred')
# Out:
# (array([ 4.,  3.,  5., 14., 15., 12., 13.,  8.,  4.,  2.]),
#  array([-2.69407443, -2.15437062, -1.6146668 , -1.07496299, -0.53525918,
#          0.00444464,  0.54414845,  1.08385226,  1.62355608,  2.16325989,
#          2.7029637 ]),
#  <BarContainer object of 10 artists>)

# %%
#to veiw both these histograms on the same plot

# %%
plt.hist(dataset1,density=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)                                  #DENSITY WAS USED IN PLACE OF NORMAD
# Out:
# (array([0.0463217 , 0.13896511, 0.0463217 , 0.09264341, 0.0463217 ,
#         0.18528681, 0.32425192, 0.32425192, 0.27793022, 0.41689533,
#         0.23160852, 0.32425192, 0.27793022, 0.32425192, 0.09264341,
#         0.27793022, 0.0463217 , 0.13896511, 0.0463217 , 0.0463217 ]),
#  array([-2.69407443, -2.42422252, -2.15437062, -1.88451871, -1.6146668 ,
#         -1.3448149 , -1.07496299, -0.80511108, -0.53525918, -0.26540727,
#          0.00444464,  0.27429654,  0.54414845,  0.81400036,  1.08385226,
#          1.35370417,  1.62355608,  1.89340798,  2.16325989,  2.4331118 ,
#          2.7029637 ]),
#  <BarContainer object of 20 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
#representing the data as a joint distribution

# %%
sns.jointplot(data1,data2)
# Out:
# C:\Users\Bright\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#FOR A MORE CONCISE PICTURE

# %%
sns.jointplot(data1,data2,kind='hex')
# Out:
# C:\Users\Bright\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
